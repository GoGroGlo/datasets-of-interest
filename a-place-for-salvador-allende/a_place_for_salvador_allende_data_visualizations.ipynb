# %% [markdown]
# # A Place for Salvador Allende: Data Visualizations

# %% [markdown]
# ## Data preparation

# %%
import pandas as pd
import matplotlib

# import our investigation table
allende = pd.read_excel('a_place_for_salvador_allende_investigation.xlsx', header=0, index_col=0, true_values=[float(1),int(1.0)])
allende.head(5)
# Out:
#                                                 name      type
# id
# 1                                   Salvador Allende    street  \
# 2                             Plaza Salvador Allende      park
# 3                     Plaza Mirador Salvador Allende      park
# 4                                     Pasaje Allende    street
# 5   Monumento al último discurso de Salvador Allende  monument
#
#             region country              locale_1    locale_2     locale_3
# id
# 1   South America    Chile             Los Lagos      Chiloé        Ancud  \
# 2   South America    Chile                Biobío  Concepción         Lota
# 3   South America    Chile                Biobío  Concepción         Lota
# 4   South America    Chile  Región Metropolitana    Santiago     Santiago
# 5   South America    Chile  Región Metropolitana    Santiago  San Joaquín
#
#          locale_4 locale_5 zip_code  ...  former_name  verified_in_maps
# id                                   ...
# 1   Bórquez Solar      NaN  5710000  ...          NaN                 1  \
# 2             NaN      NaN  4190000  ...          NaN                 1
# 3         Colcura      NaN      NaN  ...          NaN                 0
# 4             NaN      NaN  8370403  ...          NaN                 1
# 5             NaN      NaN      NaN  ...          NaN                 1
#
#                              openstreetmap_link
# id
# 1   https://www.openstreetmap.org/way/795668829  \
# 2   https://www.openstreetmap.org/way/566237673
# 3                                           NaN
# 4   https://www.openstreetmap.org/way/300049158
# 5                                           NaN
#
#                          google_maps_link
# id
# 1   https://goo.gl/maps/47DsF1gVCfG7i5g7A  \
# 2   https://goo.gl/maps/M6LT2AqH6cZfBaLe6
# 3                                     NaN
# 4   https://goo.gl/maps/DZFGaGnNi1utVVgR8
# 5   https://goo.gl/maps/7u9Zo6Q9TdySTihPA
#
#                                       abacq_reference socialist_influence
# id
# 1   http://www.abacq.org/calle/index.php?2007/02/1...                   0  \
# 2   http://www.abacq.org/calle/index.php?2013/06/2...                   0
# 3   http://www.abacq.org/calle/index.php?2007/02/1...                   0
# 4   http://www.abacq.org/calle/index.php?2012/12/0...                   0
# 5   http://www.abacq.org/calle/index.php?2011/06/2...                   0
#
#    democrat_influence chilean_influence how_allende_died erratum
# id
# 1                   0                 1              NaN       0
# 2                   0                 1              NaN       0
# 3                   0                 1              NaN       0
# 4                   0                 1              NaN       0
# 5                   0                 1              NaN       0
#
# [5 rows x 29 columns]

# %%
# normalize oldest_known_month and oldest_known_day
# allende.erratum.astype('int64')
allende.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 780 entries, 1 to 780
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 780 non-null    object
#  1   type                 780 non-null    object
#  2   region               780 non-null    object
#  3   country              780 non-null    object
#  4   locale_1             780 non-null    object
#  5   locale_2             771 non-null    object
#  6   locale_3             758 non-null    object
#  7   locale_4             667 non-null    object
#  8   locale_5             523 non-null    object
#  9   zip_code             711 non-null    object
#  10  latitude             744 non-null    float64
#  11  longitude            744 non-null    float64
#  12  oldest_known_year    780 non-null    int64
#  13  oldest_known_month   731 non-null    float64
#  14  oldest_known_day     562 non-null    float64
#  15  oldest_known_source  780 non-null    object
#  16  desc                 188 non-null    object
#  17  desc_language        189 non-null    object
#  18  alt_name             17 non-null     object
#  19  former_name          21 non-null     object
#  20  verified_in_maps     780 non-null    int64
#  21  openstreetmap_link   695 non-null    object
#  22  google_maps_link     728 non-null    object
#  23  abacq_reference      716 non-null    object
#  24  socialist_influence  780 non-null    int64
#  25  democrat_influence   780 non-null    int64
#  26  chilean_influence    780 non-null    int64
#  27  how_allende_died     56 non-null     object
#  28  erratum              780 non-null    int64
# dtypes: float64(4), int64(6), object(19)
# memory usage: 182.8+ KB

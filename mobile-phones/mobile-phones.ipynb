# %% [markdown]
# # Mobile Phones

# %% [markdown]
# ## Import and cleanup

# %% [markdown]
# Let's start with importing important modules and loading the `phones` table.

# %%
import pandas as pd
import numpy as np
from datetime import date
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
from math import nan
import re

# %%
# import from CSV
phones = pd.read_csv("phone_dataset.csv")

# quick view of what the table contains
print('---------- Quick view of the phones dataset ----------')
print('Rows, columns:', phones.shape, '\n')
print(phones.head(15), '\n')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # import from CSV
# ----> 2 phones = pd.read_csv("phone_dataset.csv")
#       4 # quick view of what the table contains
#       5 print('---------- Quick view of the phones dataset ----------')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:1973, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 40 fields in line 821, saw 41

# %% [markdown]
# We encountered this error while trying to import the data:
#
# > `ParserError: Error tokenizing data. C error: Expected 40 fields in line 821, saw 41`
#
# This is due to errors introduced by the web scraping process. Maybe there are more rows with this problem, so we'll find a way to skip these problematic rows.

# %%
# import from CSV, warn of bad lines and then skip them
phones = pd.read_csv("phone_dataset.csv", on_bad_lines='warn')

# quick view of what the table contains
print('---------- Quick view of the phones dataset ----------')
print('Rows, columns:', phones.shape, '\n')
print(phones.head(15), '\n')
# Out:
# ---------- Quick view of the phones dataset ----------
# Rows, columns: (8628, 40)
#
#    brand                 model        network_technology  \
# 0   Acer         Iconia Talk S          GSM / HSPA / LTE
# 1   Acer        Liquid Z6 Plus          GSM / HSPA / LTE
# 2   Acer             Liquid Z6          GSM / HSPA / LTE
# 3   Acer  Iconia Tab 10 A3-A40  No cellular connectivity
# 4   Acer             Liquid X2          GSM / HSPA / LTE
# 5   Acer         Liquid Jade 2          GSM / HSPA / LTE
# 6   Acer      Liquid Zest Plus          GSM / HSPA / LTE
# 7   Acer           Liquid Zest          GSM / HSPA / LTE
# 8   Acer            Predator 8  No cellular connectivity
# 9   Acer     Liquid Jade Primo          GSM / HSPA / LTE
# 10  Acer           Liquid Z330          GSM / HSPA / LTE
# 11  Acer           Liquid Z320                GSM / HSPA
# 12  Acer          Liquid Z630S          GSM / HSPA / LTE
# 13  Acer           Liquid Z630          GSM / HSPA / LTE
# 14  Acer          Liquid Z530S          GSM / HSPA / LTE
#
#                                              2G_bands  \
# 0         GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 1   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 2   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 3                                                 N/A
# 4                        GSM 850 / 900 / 1800 / 1900
# 5         GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 6   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 7   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 8                                                 N/A
# 9         GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 10  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 11  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 12  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 13  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 14  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
#
#                                           3G_bands  \
# 0                         HSDPA 850 / 1900 / 2100
# 1                                            HSDPA
# 2                                            HSDPA
# 3                                              NaN
# 4         HSDPA 900 / 1900 / 2100 - Europe| Taiwan
# 5                                HSDPA 900 / 2100
# 6                                            HSDPA
# 7                   HSDPA 850 / 900 / 1900 / 2100
# 8                                              NaN
# 9   HSDPA 850 / 900 / 1900 / 2100 - Europe/ Taiwan
# 10                                           HSDPA
# 11                                           HSDPA
# 12                        HSDPA 900 / 1900 / 2100
# 13                                           HSDPA
# 14                                           HSDPA
#
#                                              4G_bands  \
# 0   LTE band 1(2100)| 3(1800)| 7(2600)| 8(900)| 20...
# 1                                                 LTE
# 2                                                 LTE
# 3                                                 NaN
# 4               LTE 800 / 1800 / 2100 / 2600 - Europe
# 5                                                 LTE
# 6                                                 LTE
# 7                                                 LTE
# 8                                                 NaN
# 9               LTE 800 / 1800 / 2100 / 2600 - Europe
# 10                                                LTE
# 11                                                NaN
# 12                                                LTE
# 13                                                LTE
# 14                                                LTE
#
#                                         network_speed GPRS EDGE  \
# 0           HSPA 42.2/11.5 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 1           HSPA 42.2/5.76 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 2                                           HSPA  LTE  Yes  Yes
# 3                                                 NaN   No   No
# 4           HSPA 42.2/5.76 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 5           HSPA 42.2/5.76 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 6                                           HSPA  LTE  Yes  Yes
# 7                          HSPA  LTE Cat4 150/50 Mbps  Yes  Yes
# 8                                                 NaN   No   No
# 9   HSPA 42.2/5.76 Mbps  LTE-A (2CA) Cat6 300/50 Mbps  Yes  Yes
# 10                                          HSPA  LTE  Yes  Yes
# 11                                HSPA 42.2/5.76 Mbps  Yes  Yes
# 12                                          HSPA  LTE  Yes  Yes
# 13                                          HSPA  LTE  Yes  Yes
# 14                                          HSPA  LTE  Yes  Yes
#
#           announced  ...           bluetooth                     GPS  NFC  \
# 0      2016  August  ...           4.0| A2DP  Yes with A-GPS GLONASS  NaN
# 1      2016  August  ...           4.0| A2DP          Yes with A-GPS  NaN
# 2      2016  August  ...                 Yes          Yes with A-GPS  NaN
# 3       2016  April  ...                 Yes                     NaN  NaN
# 4       2015  April  ...       4.0| A2DP| LE          Yes with A-GPS  NaN
# 5    2016  February  ...       4.0| A2DP| LE          Yes with A-GPS  NaN
# 6       2016  April  ...                 Yes          Yes with A-GPS  NaN
# 7    2016  February  ...           4.0| A2DP          Yes with A-GPS  NaN
# 8   2015  September  ...       4.0| A2DP| LE                     NaN  NaN
# 9   2015  September  ...  4.0| A2DP| LE| EDR          Yes with A-GPS  NaN
# 10  2015  September  ...           4.0| A2DP          Yes with A-GPS  NaN
# 11  2015  September  ...           4.0| A2DP          Yes with A-GPS  NaN
# 12  2015  September  ...           4.0| A2DP          Yes with A-GPS  NaN
# 13  2015  September  ...           4.0| A2DP          Yes with A-GPS  NaN
# 14  2015  September  ...           4.0| A2DP          Yes with A-GPS  NaN
#
#        radio                                   USB  \
# 0   FM radio                          microUSB 2.0
# 1   FM radio                          microUSB 2.0
# 2   FM radio                          microUSB 2.0
# 3         No                          microUSB 2.0
# 4   FM radio                          microUSB 2.0
# 5   FM radio                          microUSB 2.0
# 6   FM radio                          microUSB 2.0
# 7   FM radio                          microUSB 2.0
# 8         No                          microUSB 2.0
# 9   FM radio  3.1| Type-C 1.0 reversible connector
# 10  FM radio                          microUSB 2.0
# 11  FM radio                          microUSB 2.0
# 12  FM radio           microUSB 2.0| USB On-The-Go
# 13  FM radio           microUSB 2.0| USB On-The-Go
# 14  FM radio                          microUSB 2.0
#
#                                               sensors  \
# 0                            Accelerometer| proximity
# 1   Fingerprint (front-mounted)| accelerometer| pr...
# 2                            Accelerometer| proximity
# 3                                       Accelerometer
# 4                   Accelerometer| proximity| compass
# 5             Accelerometer| gyro| proximity| compass
# 6                   Accelerometer| proximity| compass
# 7                   Accelerometer| proximity| compass
# 8                                                 Yes
# 9             Accelerometer| gyro| proximity| compass
# 10                           Accelerometer| proximity
# 11                           Accelerometer| proximity
# 12                  Accelerometer| proximity| compass
# 13                  Accelerometer| proximity| compass
# 14                           Accelerometer| proximity
#
#                                              battery  \
# 0   Non-removable Li-Ion 3400 mAh battery (12.92 Wh)
# 1                   Removable Li-Po 4080 mAh battery
# 2                  Removable Li-Ion 2000 mAh battery
# 3                       Non-removable Li-Ion battery
# 4                   Removable Li-Po 4020 mAh battery
# 5                                                NaN
# 6              Non-removable Li-Ion 5000 mAh battery
# 7                  Removable Li-Ion 2000 mAh battery
# 8               Non-removable Li-Po 4420 mAh battery
# 9               Non-removable Li-Po 2870 mAh battery
# 10                 Removable Li-Ion 2000 mAh battery
# 11                  Removable Li-Po 2000 mAh battery
# 12        Removable Li-Po 4000 mAh battery (15.2 Wh)
# 13                 Removable Li-Ion 4000 mAh battery
# 14                 Removable Li-Ion 2420 mAh battery
#
#                       colors approx_price_EUR  \
# 0                      Black            170.0
# 1               Black| White            250.0
# 2               Black| White            120.0
# 3                      Black            230.0
# 4                Black| Gold            230.0
# 5                      Black              NaN
# 6                Blue| White            200.0
# 7               Black| White            110.0
# 8               Black/Silver            350.0
# 9                      Black            220.0
# 10  Mystic Black| Pure White            110.0
# 11                Pure White             90.0
# 12               Black| Gold              NaN
# 13                     Black            200.0
# 14              Black| White              NaN
#
#                                               img_url
# 0   http://cdn2.gsmarena.com/vv/bigpic/acer-iconia...
# 1   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 2   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 3   http://cdn2.gsmarena.com/vv/bigpic/acer-iconia...
# 4   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 5   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 6   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 7    http://cdn2.gsmarena.com/vv/bigpic/acer-zest.jpg
# 8   http://cdn2.gsmarena.com/vv/bigpic/acer-predat...
# 9   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 10  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 11  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 12  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 13  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 14  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
#
# [15 rows x 40 columns]
# Skipping line 821: expected 40 fields, saw 41
# Skipping line 6060: expected 40 fields, saw 41
# Skipping line 6663: expected 40 fields, saw 41

# %% [markdown]
# There are only three problematic rows, so we can skip them for now.

# %%
# quick view of what columns we have
print(phones.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8628 entries, 0 to 8627
# Data columns (total 40 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   brand               8628 non-null   object
#  1   model               8628 non-null   object
#  2   network_technology  8628 non-null   object
#  3   2G_bands            8628 non-null   object
#  4   3G_bands            4856 non-null   object
#  5   4G_bands            1603 non-null   object
#  6   network_speed       4883 non-null   object
#  7   GPRS                8596 non-null   object
#  8   EDGE                8605 non-null   object
#  9   announced           8613 non-null   object
#  10  status              8628 non-null   object
#  11  dimentions          8609 non-null   object
#  12  weight_g            7679 non-null   object
#  13  weight_oz           7679 non-null   object
#  14  SIM                 8627 non-null   object
#  15  display_type        8624 non-null   object
#  16  display_resolution  7414 non-null   object
#  17  display_size        8581 non-null   object
#  18  OS                  4905 non-null   object
#  19  CPU                 4834 non-null   object
#  20  Chipset             3690 non-null   object
#  21  GPU                 3492 non-null   object
#  22  memory_card         8628 non-null   object
#  23  internal_memory     6806 non-null   object
#  24  RAM                 4656 non-null   object
#  25  primary_camera      7436 non-null   object
#  26  secondary_camera    7405 non-null   object
#  27  loud_speaker        8628 non-null   object
#  28  audio_jack          8560 non-null   object
#  29  WLAN                8624 non-null   object
#  30  bluetooth           8609 non-null   object
#  31  GPS                 8599 non-null   object
#  32  NFC                 792 non-null    object
#  33  radio               8534 non-null   object
#  34  USB                 7725 non-null   object
#  35  sensors             4588 non-null   object
#  36  battery             8626 non-null   object
#  37  colors              8026 non-null   object
#  38  approx_price_EUR    5003 non-null   float64
#  39  img_url             8628 non-null   object
# dtypes: float64(1), object(39)
# memory usage: 2.6+ MB
# None

# %% [markdown]
# We are only interested in phones that actually made it to the market, not ones that are cancelled, abandoned, coming soon, or something similar. In order to filter out phones like these, we need to find out all available kinds of `status`.

# %%
# refine 'status' column
# for index, value in phones['status'].items():
#     if 'Available' in value:
#         phones.at[index, 'status'] = 'Available'
#     elif 'Coming soon' in value:
#         phones.at[index, 'status'] = 'Coming soon'

# retrieve unique values of 'status'
# print('---------- Phone statuses ----------')
# print(phones['status'].unique().tolist(), '\n')
# ['Available', 'Discontinued', 'Coming soon', 'Cancelled']


# only include Available and Discontinued phones
for index, value in phones.iterrows():
    if 'Cancelled' in value['status']:
        phones.at[index, 'status'] = nan
    elif 'Coming soon' in value['status']:
        phones.at[index, 'status'] = nan

phones = phones.dropna(subset=['status'])

print('---------- Phones that are or were available in the market ----------')
print('Rows, columns:', phones.shape, '\n')
print(phones.head(15), '\n')
# Out:
# ---------- Phones that are or were available in the market ----------
# Rows, columns: (8380, 40)
#
#    brand                 model        network_technology  \
# 0   Acer         Iconia Talk S          GSM / HSPA / LTE
# 1   Acer        Liquid Z6 Plus          GSM / HSPA / LTE
# 2   Acer             Liquid Z6          GSM / HSPA / LTE
# 3   Acer  Iconia Tab 10 A3-A40  No cellular connectivity
# 4   Acer             Liquid X2          GSM / HSPA / LTE
# 5   Acer         Liquid Jade 2          GSM / HSPA / LTE
# 6   Acer      Liquid Zest Plus          GSM / HSPA / LTE
# 7   Acer           Liquid Zest          GSM / HSPA / LTE
# 8   Acer            Predator 8  No cellular connectivity
# 9   Acer     Liquid Jade Primo          GSM / HSPA / LTE
# 10  Acer           Liquid Z330          GSM / HSPA / LTE
# 11  Acer           Liquid Z320                GSM / HSPA
# 12  Acer          Liquid Z630S          GSM / HSPA / LTE
# 13  Acer           Liquid Z630          GSM / HSPA / LTE
# 14  Acer          Liquid Z530S          GSM / HSPA / LTE
#
#                                              2G_bands  \
# 0         GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 1   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 2   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 3                                                 N/A
# 4                        GSM 850 / 900 / 1800 / 1900
# 5         GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 6   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 7   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 8                                                 N/A
# 9         GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 10  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 11  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 12  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 13  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 14  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
#
#                                           3G_bands  \
# 0                         HSDPA 850 / 1900 / 2100
# 1                                            HSDPA
# 2                                            HSDPA
# 3                                              NaN
# 4         HSDPA 900 / 1900 / 2100 - Europe| Taiwan
# 5                                HSDPA 900 / 2100
# 6                                            HSDPA
# 7                   HSDPA 850 / 900 / 1900 / 2100
# 8                                              NaN
# 9   HSDPA 850 / 900 / 1900 / 2100 - Europe/ Taiwan
# 10                                           HSDPA
# 11                                           HSDPA
# 12                        HSDPA 900 / 1900 / 2100
# 13                                           HSDPA
# 14                                           HSDPA
#
#                                              4G_bands  \
# 0   LTE band 1(2100)| 3(1800)| 7(2600)| 8(900)| 20...
# 1                                                 LTE
# 2                                                 LTE
# 3                                                 NaN
# 4               LTE 800 / 1800 / 2100 / 2600 - Europe
# 5                                                 LTE
# 6                                                 LTE
# 7                                                 LTE
# 8                                                 NaN
# 9               LTE 800 / 1800 / 2100 / 2600 - Europe
# 10                                                LTE
# 11                                                NaN
# 12                                                LTE
# 13                                                LTE
# 14                                                LTE
#
#                                         network_speed GPRS EDGE  \
# 0           HSPA 42.2/11.5 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 1           HSPA 42.2/5.76 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 2                                           HSPA  LTE  Yes  Yes
# 3                                                 NaN   No   No
# 4           HSPA 42.2/5.76 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 5           HSPA 42.2/5.76 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 6                                           HSPA  LTE  Yes  Yes
# 7                          HSPA  LTE Cat4 150/50 Mbps  Yes  Yes
# 8                                                 NaN   No   No
# 9   HSPA 42.2/5.76 Mbps  LTE-A (2CA) Cat6 300/50 Mbps  Yes  Yes
# 10                                          HSPA  LTE  Yes  Yes
# 11                                HSPA 42.2/5.76 Mbps  Yes  Yes
# 12                                          HSPA  LTE  Yes  Yes
# 13                                          HSPA  LTE  Yes  Yes
# 14                                          HSPA  LTE  Yes  Yes
#
#           announced  ...           bluetooth                     GPS  NFC  \
# 0      2016  August  ...           4.0| A2DP  Yes with A-GPS GLONASS  NaN
# 1      2016  August  ...           4.0| A2DP          Yes with A-GPS  NaN
# 2      2016  August  ...                 Yes          Yes with A-GPS  NaN
# 3       2016  April  ...                 Yes                     NaN  NaN
# 4       2015  April  ...       4.0| A2DP| LE          Yes with A-GPS  NaN
# 5    2016  February  ...       4.0| A2DP| LE          Yes with A-GPS  NaN
# 6       2016  April  ...                 Yes          Yes with A-GPS  NaN
# 7    2016  February  ...           4.0| A2DP          Yes with A-GPS  NaN
# 8   2015  September  ...       4.0| A2DP| LE                     NaN  NaN
# 9   2015  September  ...  4.0| A2DP| LE| EDR          Yes with A-GPS  NaN
# 10  2015  September  ...           4.0| A2DP          Yes with A-GPS  NaN
# 11  2015  September  ...           4.0| A2DP          Yes with A-GPS  NaN
# 12  2015  September  ...           4.0| A2DP          Yes with A-GPS  NaN
# 13  2015  September  ...           4.0| A2DP          Yes with A-GPS  NaN
# 14  2015  September  ...           4.0| A2DP          Yes with A-GPS  NaN
#
#        radio                                   USB  \
# 0   FM radio                          microUSB 2.0
# 1   FM radio                          microUSB 2.0
# 2   FM radio                          microUSB 2.0
# 3         No                          microUSB 2.0
# 4   FM radio                          microUSB 2.0
# 5   FM radio                          microUSB 2.0
# 6   FM radio                          microUSB 2.0
# 7   FM radio                          microUSB 2.0
# 8         No                          microUSB 2.0
# 9   FM radio  3.1| Type-C 1.0 reversible connector
# 10  FM radio                          microUSB 2.0
# 11  FM radio                          microUSB 2.0
# 12  FM radio           microUSB 2.0| USB On-The-Go
# 13  FM radio           microUSB 2.0| USB On-The-Go
# 14  FM radio                          microUSB 2.0
#
#                                               sensors  \
# 0                            Accelerometer| proximity
# 1   Fingerprint (front-mounted)| accelerometer| pr...
# 2                            Accelerometer| proximity
# 3                                       Accelerometer
# 4                   Accelerometer| proximity| compass
# 5             Accelerometer| gyro| proximity| compass
# 6                   Accelerometer| proximity| compass
# 7                   Accelerometer| proximity| compass
# 8                                                 Yes
# 9             Accelerometer| gyro| proximity| compass
# 10                           Accelerometer| proximity
# 11                           Accelerometer| proximity
# 12                  Accelerometer| proximity| compass
# 13                  Accelerometer| proximity| compass
# 14                           Accelerometer| proximity
#
#                                              battery  \
# 0   Non-removable Li-Ion 3400 mAh battery (12.92 Wh)
# 1                   Removable Li-Po 4080 mAh battery
# 2                  Removable Li-Ion 2000 mAh battery
# 3                       Non-removable Li-Ion battery
# 4                   Removable Li-Po 4020 mAh battery
# 5                                                NaN
# 6              Non-removable Li-Ion 5000 mAh battery
# 7                  Removable Li-Ion 2000 mAh battery
# 8               Non-removable Li-Po 4420 mAh battery
# 9               Non-removable Li-Po 2870 mAh battery
# 10                 Removable Li-Ion 2000 mAh battery
# 11                  Removable Li-Po 2000 mAh battery
# 12        Removable Li-Po 4000 mAh battery (15.2 Wh)
# 13                 Removable Li-Ion 4000 mAh battery
# 14                 Removable Li-Ion 2420 mAh battery
#
#                       colors approx_price_EUR  \
# 0                      Black            170.0
# 1               Black| White            250.0
# 2               Black| White            120.0
# 3                      Black            230.0
# 4                Black| Gold            230.0
# 5                      Black              NaN
# 6                Blue| White            200.0
# 7               Black| White            110.0
# 8               Black/Silver            350.0
# 9                      Black            220.0
# 10  Mystic Black| Pure White            110.0
# 11                Pure White             90.0
# 12               Black| Gold              NaN
# 13                     Black            200.0
# 14              Black| White              NaN
#
#                                               img_url
# 0   http://cdn2.gsmarena.com/vv/bigpic/acer-iconia...
# 1   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 2   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 3   http://cdn2.gsmarena.com/vv/bigpic/acer-iconia...
# 4   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 5   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 6   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 7    http://cdn2.gsmarena.com/vv/bigpic/acer-zest.jpg
# 8   http://cdn2.gsmarena.com/vv/bigpic/acer-predat...
# 9   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 10  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 11  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 12  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 13  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
# 14  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...
#
# [15 rows x 40 columns]

# %% [markdown]
# We have a column called `announced` which is the month and year when a phone was announced. However, some phones don't have the exact month in which they're released, only the quarter. To accommodate for these we'll do the following column changes:
# * Change `announced` to a date format for phones with an available month and date of announcement. The day will always be "01". This will be null for phones whose exact announcement month is unknown.
# * Create `announced_year` and `announced_quarter` containing the year and quarter of announcement, respectively.
#
# _Note:_ The `announced` values are more messy than I expected, so cleaning this up will take some time. For now, I got bored and moved on to other datasets.

# %%
# normalize months and quarters
month_to_num = {
    'January'   : '01',
    'February'  : '02',
    'March'     : '03',
    'April'     : '04',
    'May'       : '05',
    'June'      : '06',
    'July'      : '07',
    'August'    : '08',
    'September' : '09',
    'October'   : '10',
    'November'  : '11',
    'December'  : '12'
}

get_quarters = {
    '1Q'            : 'Q1',
    '2Q'            : 'Q2',
    '3Q'            : 'Q3',
    '4Q'            : 'Q4',
    'Q1'            : 'Q1',
    'Q2'            : 'Q2',
    'Q3'            : 'Q3',
    'Q4'            : 'Q4',
    'January'       : 'Q1',
    'February'      : 'Q1',
    'March'         : 'Q1',
    'April'         : 'Q2',
    'May'           : 'Q2',
    'June'          : 'Q2',
    'July'          : 'Q3',
    'August'        : 'Q3',
    'September'     : 'Q3',
    'October'       : 'Q4',
    'November'      : 'Q4',
    'December'      : 'Q4'
}


# these functions extract the year, month, and quarter from the original 'announced' column
def get_year_announced(x):
    if isinstance(x, (pd.Timestamp)):
        x.isoformat()
    try:
        year = re.search(r'(^\d{4})', x)
        year = int(year.group(1))
    except:
        return nan
    else:
        return year

def get_month_announced(x):
    try:
       month = re.search(r'^\d{4}\s*(\w*)', x)
       month = month_to_num[month.group(1)]
    except:
        return nan
    else:
        return month

def get_quarter_announced(x):
    try:
        quarter = re.search(r'^\d{4}\s*(\w*)', x)
        quarter = get_quarters[quarter.group(1)]
    except:
        return nan
    else:
        return quarter


# quick tests to see if the functions are working as expected
print(get_year_announced('Exp. announcement 2012  August'))
print(get_month_announced('2009  March. Released 2009  May'))
print(get_quarter_announced('2009  March. Released 2009  May'))



# create 'announced_year' column
phones['announced_year'[:]] = ''

for index, value in phones.iterrows():
    phones.at[index, 'announced_year'] = get_year_announced(value['announced'])


# create 'announced_quarter' value
phones['announced_quarter'[:]] = ''

for index, value in phones.iterrows():
    phones.at[index, 'announced_quarter'] = get_quarter_announced(value['announced'])


# convert 'announced' column to dates
for index, value in phones['announced'].items():
    if isinstance(value, (pd.Timestamp)):
        phones.at[index, 'announced'] = pd.to_datetime(value, format='%Y-%m-%d')
    elif type(value) is str:
        if 'Q' in str(value):
            phones.at[index, 'announced'] = ''
        else:
            try:
                phones.at[index, 'announced'] = pd.to_datetime(f'{get_year_announced(value)}-{get_month_announced(value)}-01', format='%Y-%m-%d')
            except:
                phones.at[index, 'announced'] = ''


# quick view of how 'announced' column values look like
# print(phones['announced'].unique().tolist(), '\n')

# quick view of what the table contains
print('---------- Quick view of the phones dataset ----------')
print(phones.head(15), '\n')
# Out:
# nan
# 03
# Q1
# ---------- Quick view of the phones dataset ----------
#    brand                 model        network_technology  \
# 0   Acer         Iconia Talk S          GSM / HSPA / LTE
# 1   Acer        Liquid Z6 Plus          GSM / HSPA / LTE
# 2   Acer             Liquid Z6          GSM / HSPA / LTE
# 3   Acer  Iconia Tab 10 A3-A40  No cellular connectivity
# 4   Acer             Liquid X2          GSM / HSPA / LTE
# 5   Acer         Liquid Jade 2          GSM / HSPA / LTE
# 6   Acer      Liquid Zest Plus          GSM / HSPA / LTE
# 7   Acer           Liquid Zest          GSM / HSPA / LTE
# 8   Acer            Predator 8  No cellular connectivity
# 9   Acer     Liquid Jade Primo          GSM / HSPA / LTE
# 10  Acer           Liquid Z330          GSM / HSPA / LTE
# 11  Acer           Liquid Z320                GSM / HSPA
# 12  Acer          Liquid Z630S          GSM / HSPA / LTE
# 13  Acer           Liquid Z630          GSM / HSPA / LTE
# 14  Acer          Liquid Z530S          GSM / HSPA / LTE
#
#                                              2G_bands  \
# 0         GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 1   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 2   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 3                                                 N/A
# 4                        GSM 850 / 900 / 1800 / 1900
# 5         GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 6   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 7   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 8                                                 N/A
# 9         GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 10  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 11  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 12  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 13  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 14  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
#
#                                           3G_bands  \
# 0                         HSDPA 850 / 1900 / 2100
# 1                                            HSDPA
# 2                                            HSDPA
# 3                                              NaN
# 4         HSDPA 900 / 1900 / 2100 - Europe| Taiwan
# 5                                HSDPA 900 / 2100
# 6                                            HSDPA
# 7                   HSDPA 850 / 900 / 1900 / 2100
# 8                                              NaN
# 9   HSDPA 850 / 900 / 1900 / 2100 - Europe/ Taiwan
# 10                                           HSDPA
# 11                                           HSDPA
# 12                        HSDPA 900 / 1900 / 2100
# 13                                           HSDPA
# 14                                           HSDPA
#
#                                              4G_bands  \
# 0   LTE band 1(2100)| 3(1800)| 7(2600)| 8(900)| 20...
# 1                                                 LTE
# 2                                                 LTE
# 3                                                 NaN
# 4               LTE 800 / 1800 / 2100 / 2600 - Europe
# 5                                                 LTE
# 6                                                 LTE
# 7                                                 LTE
# 8                                                 NaN
# 9               LTE 800 / 1800 / 2100 / 2600 - Europe
# 10                                                LTE
# 11                                                NaN
# 12                                                LTE
# 13                                                LTE
# 14                                                LTE
#
#                                         network_speed GPRS EDGE  \
# 0           HSPA 42.2/11.5 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 1           HSPA 42.2/5.76 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 2                                           HSPA  LTE  Yes  Yes
# 3                                                 NaN   No   No
# 4           HSPA 42.2/5.76 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 5           HSPA 42.2/5.76 Mbps  LTE Cat4 150/50 Mbps  Yes  Yes
# 6                                           HSPA  LTE  Yes  Yes
# 7                          HSPA  LTE Cat4 150/50 Mbps  Yes  Yes
# 8                                                 NaN   No   No
# 9   HSPA 42.2/5.76 Mbps  LTE-A (2CA) Cat6 300/50 Mbps  Yes  Yes
# 10                                          HSPA  LTE  Yes  Yes
# 11                                HSPA 42.2/5.76 Mbps  Yes  Yes
# 12                                          HSPA  LTE  Yes  Yes
# 13                                          HSPA  LTE  Yes  Yes
# 14                                          HSPA  LTE  Yes  Yes
#
#               announced  ...  NFC     radio  \
# 0   2016-08-01 00:00:00  ...  NaN  FM radio
# 1   2016-08-01 00:00:00  ...  NaN  FM radio
# 2   2016-08-01 00:00:00  ...  NaN  FM radio
# 3   2016-04-01 00:00:00  ...  NaN        No
# 4   2015-04-01 00:00:00  ...  NaN  FM radio
# 5   2016-02-01 00:00:00  ...  NaN  FM radio
# 6   2016-04-01 00:00:00  ...  NaN  FM radio
# 7   2016-02-01 00:00:00  ...  NaN  FM radio
# 8   2015-09-01 00:00:00  ...  NaN        No
# 9   2015-09-01 00:00:00  ...  NaN  FM radio
# 10  2015-09-01 00:00:00  ...  NaN  FM radio
# 11  2015-09-01 00:00:00  ...  NaN  FM radio
# 12  2015-09-01 00:00:00  ...  NaN  FM radio
# 13  2015-09-01 00:00:00  ...  NaN  FM radio
# 14  2015-09-01 00:00:00  ...  NaN  FM radio
#
#                                      USB  \
# 0                           microUSB 2.0
# 1                           microUSB 2.0
# 2                           microUSB 2.0
# 3                           microUSB 2.0
# 4                           microUSB 2.0
# 5                           microUSB 2.0
# 6                           microUSB 2.0
# 7                           microUSB 2.0
# 8                           microUSB 2.0
# 9   3.1| Type-C 1.0 reversible connector
# 10                          microUSB 2.0
# 11                          microUSB 2.0
# 12           microUSB 2.0| USB On-The-Go
# 13           microUSB 2.0| USB On-The-Go
# 14                          microUSB 2.0
#
#                                               sensors  \
# 0                            Accelerometer| proximity
# 1   Fingerprint (front-mounted)| accelerometer| pr...
# 2                            Accelerometer| proximity
# 3                                       Accelerometer
# 4                   Accelerometer| proximity| compass
# 5             Accelerometer| gyro| proximity| compass
# 6                   Accelerometer| proximity| compass
# 7                   Accelerometer| proximity| compass
# 8                                                 Yes
# 9             Accelerometer| gyro| proximity| compass
# 10                           Accelerometer| proximity
# 11                           Accelerometer| proximity
# 12                  Accelerometer| proximity| compass
# 13                  Accelerometer| proximity| compass
# 14                           Accelerometer| proximity
#
#                                              battery  \
# 0   Non-removable Li-Ion 3400 mAh battery (12.92 Wh)
# 1                   Removable Li-Po 4080 mAh battery
# 2                  Removable Li-Ion 2000 mAh battery
# 3                       Non-removable Li-Ion battery
# 4                   Removable Li-Po 4020 mAh battery
# 5                                                NaN
# 6              Non-removable Li-Ion 5000 mAh battery
# 7                  Removable Li-Ion 2000 mAh battery
# 8               Non-removable Li-Po 4420 mAh battery
# 9               Non-removable Li-Po 2870 mAh battery
# 10                 Removable Li-Ion 2000 mAh battery
# 11                  Removable Li-Po 2000 mAh battery
# 12        Removable Li-Po 4000 mAh battery (15.2 Wh)
# 13                 Removable Li-Ion 4000 mAh battery
# 14                 Removable Li-Ion 2420 mAh battery
#
#                       colors approx_price_EUR  \
# 0                      Black            170.0
# 1               Black| White            250.0
# 2               Black| White            120.0
# 3                      Black            230.0
# 4                Black| Gold            230.0
# 5                      Black              NaN
# 6                Blue| White            200.0
# 7               Black| White            110.0
# 8               Black/Silver            350.0
# 9                      Black            220.0
# 10  Mystic Black| Pure White            110.0
# 11                Pure White             90.0
# 12               Black| Gold              NaN
# 13                     Black            200.0
# 14              Black| White              NaN
#
#                                               img_url announced_year  \
# 0   http://cdn2.gsmarena.com/vv/bigpic/acer-iconia...            NaN
# 1   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
# 2   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
# 3   http://cdn2.gsmarena.com/vv/bigpic/acer-iconia...            NaN
# 4   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
# 5   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
# 6   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
# 7    http://cdn2.gsmarena.com/vv/bigpic/acer-zest.jpg            NaN
# 8   http://cdn2.gsmarena.com/vv/bigpic/acer-predat...            NaN
# 9   http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
# 10  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
# 11  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
# 12  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
# 13  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
# 14  http://cdn2.gsmarena.com/vv/bigpic/acer-liquid...            NaN
#
#    announced_quarter
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
#
# [15 rows x 42 columns]

# %% [markdown]
# ## The rise and fall of the audio jack

# %% [markdown]
# _To be continued after cleaning up the dataset..._
